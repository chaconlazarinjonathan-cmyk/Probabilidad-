# %% [markdown]
# <a href="https://colab.research.google.com/github/chaconlazarinjonathan-cmyk/Probabilidad-/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##*Probabilidad y Estadistica*
# ## **Practica 3: Tabla de Frecuencias y Regla de Sturges**
#
# ## Unidad 1
#
#
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Jonathan Chacon Lazarin

# %%
# basado en el LIBRO estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas
import random
import matplotlib.pyplot as plt #Libreria para graficar

edades = []

# Hacemos un ciclo para generar 100 numeros aleatorios qe representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint(18, 70)

    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [60, 64, 54, 27, 23, 57, 67, 28, 45, 67, 63, 64, 37, 31, 53, 32, 65, 60, 21, 40, 51, 70, 24, 68, 27, 29, 37, 51, 31, 23, 47, 48, 45, 22, 24, 58, 41, 24, 52, 46, 68, 33, 55, 39, 35, 47, 63, 27, 41, 23, 50, 59, 26, 65, 51, 56, 41, 63, 21, 19, 47, 52, 44, 28, 21, 58, 57, 58, 56, 33, 27, 57, 28, 18, 54, 34, 45, 31, 58, 49, 63, 35, 57, 69, 47, 46, 56, 29, 57, 23, 33, 22, 25, 69, 21, 25, 34, 68, 66, 47]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios

df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    60
# 1    64
# 2    54
# 3    27
# 4    23

# %%
# Calcular la tabla de distribución de frecuencias

tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 41    18           1
# 40    19           1
# 5     21           4
# 22    22           2
# 4     23           4
# 8     24           3
# 29    25           2
# 37    26           1
# 2     27           4
# 10    28           3
# 24    29           2
# 7     31           3
# 34    32           1
# 14    33           3
# 25    34           2
# 26    35           2
# 16    37           2
# 35    39           1
# 31    40           1
# 11    41           3
# 42    44           1
# 12    45           3
# 27    46           2
# 1     47           5
# 33    48           1
# 43    49           1
# 39    50           1
# 15    51           3
# 23    52           2
# 30    53           1
# 17    54           2
# 36    55           1
# 13    56           3
# 0     57           5
# 6     58           4
# 38    59           1
# 18    60           2
# 3     63           4
# 20    64           2
# 28    65           2
# 44    66           1
# 19    67           2
# 9     68           3
# 21    69           2
# 32    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 41    18           1           0.01
# 40    19           1           0.01
# 5     21           4           0.04
# 22    22           2           0.02
# 4     23           4           0.04
# 8     24           3           0.03
# 29    25           2           0.02
# 37    26           1           0.01
# 2     27           4           0.04
# 10    28           3           0.03
# 24    29           2           0.02
# 7     31           3           0.03
# 34    32           1           0.01
# 14    33           3           0.03
# 25    34           2           0.02
# 26    35           2           0.02
# 16    37           2           0.02
# 35    39           1           0.01
# 31    40           1           0.01
# 11    41           3           0.03
# 42    44           1           0.01
# 12    45           3           0.03
# 27    46           2           0.02
# 1     47           5           0.05
# 33    48           1           0.01
# 43    49           1           0.01
# 39    50           1           0.01
# 15    51           3           0.03
# 23    52           2           0.02
# 30    53           1           0.01
# 17    54           2           0.02
# 36    55           1           0.01
# 13    56           3           0.03
# 0     57           5           0.05
# 6     58           4           0.04
# 38    59           1           0.01
# 18    60           2           0.02
# 3     63           4           0.04
# 20    64           2           0.02
# 28    65           2           0.02
# 44    66           1           0.01
# 19    67           2           0.02
# 9     68           3           0.03
# 21    69           2           0.02
# 32    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 41    18           1           0.01              1.0
# 40    19           1           0.01              1.0
# 5     21           4           0.04              4.0
# 22    22           2           0.02              2.0
# 4     23           4           0.04              4.0
# 8     24           3           0.03              3.0
# 29    25           2           0.02              2.0
# 37    26           1           0.01              1.0
# 2     27           4           0.04              4.0
# 10    28           3           0.03              3.0
# 24    29           2           0.02              2.0
# 7     31           3           0.03              3.0
# 34    32           1           0.01              1.0
# 14    33           3           0.03              3.0
# 25    34           2           0.02              2.0
# 26    35           2           0.02              2.0
# 16    37           2           0.02              2.0
# 35    39           1           0.01              1.0
# 31    40           1           0.01              1.0
# 11    41           3           0.03              3.0
# 42    44           1           0.01              1.0
# 12    45           3           0.03              3.0
# 27    46           2           0.02              2.0
# 1     47           5           0.05              5.0
# 33    48           1           0.01              1.0
# 43    49           1           0.01              1.0
# 39    50           1           0.01              1.0
# 15    51           3           0.03              3.0
# 23    52           2           0.02              2.0
# 30    53           1           0.01              1.0
# 17    54           2           0.02              2.0
# 36    55           1           0.01              1.0
# 13    56           3           0.03              3.0
# 0     57           5           0.05              5.0
# 6     58           4           0.04              4.0
# 38    59           1           0.01              1.0
# 18    60           2           0.02              2.0
# 3     63           4           0.04              4.0
# 20    64           2           0.02              2.0
# 28    65           2           0.02              2.0
# 44    66           1           0.01              1.0
# 19    67           2           0.02              2.0
# 9     68           3           0.03              3.0
# 21    69           2           0.02              2.0
# 32    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 41    18           1           0.01              1.0               1
# 40    19           1           0.01              1.0               2
# 5     21           4           0.04              4.0               6
# 22    22           2           0.02              2.0               8
# 4     23           4           0.04              4.0              12
# 8     24           3           0.03              3.0              15
# 29    25           2           0.02              2.0              17
# 37    26           1           0.01              1.0              18
# 2     27           4           0.04              4.0              22
# 10    28           3           0.03              3.0              25
# 24    29           2           0.02              2.0              27
# 7     31           3           0.03              3.0              30
# 34    32           1           0.01              1.0              31
# 14    33           3           0.03              3.0              34
# 25    34           2           0.02              2.0              36
# 26    35           2           0.02              2.0              38
# 16    37           2           0.02              2.0              40
# 35    39           1           0.01              1.0              41
# 31    40           1           0.01              1.0              42
# 11    41           3           0.03              3.0              45
# 42    44           1           0.01              1.0              46
# 12    45           3           0.03              3.0              49
# 27    46           2           0.02              2.0              51
# 1     47           5           0.05              5.0              56
# 33    48           1           0.01              1.0              57
# 43    49           1           0.01              1.0              58
# 39    50           1           0.01              1.0              59
# 15    51           3           0.03              3.0              62
# 23    52           2           0.02              2.0              64
# 30    53           1           0.01              1.0              65
# 17    54           2           0.02              2.0              67
# 36    55           1           0.01              1.0              68
# 13    56           3           0.03              3.0              71
# 0     57           5           0.05              5.0              76
# 6     58           4           0.04              4.0              80
# 38    59           1           0.01              1.0              81
# 18    60           2           0.02              2.0              83
# 3     63           4           0.04              4.0              87
# 20    64           2           0.02              2.0              89
# 28    65           2           0.02              2.0              91
# 44    66           1           0.01              1.0              92
# 19    67           2           0.02              2.0              94
# 9     68           3           0.03              3.0              97
# 21    69           2           0.02              2.0              99
# 32    70           1           0.01              1.0             100

# %% [markdown]
# #**Regla de Sturges**
# ##Es una regla que sirve para calcular el número de clases o intervalos adecuado en los que se debe dividir un conjunto de datos.
# ##Establece que el número de clases es igual a uno más el logaritmo en base dos del número total de datos.
#
# c = 1 + log₂(N)
#
# donde N es el tamaño de nuestra muestra

# %%
# importamos la librería math de funciones matemáticas
import math

# %%
# se vuelve a usar la tabla de edades
print(edades)
# Out:
# [60, 64, 54, 27, 23, 57, 67, 28, 45, 67, 63, 64, 37, 31, 53, 32, 65, 60, 21, 40, 51, 70, 24, 68, 27, 29, 37, 51, 31, 23, 47, 48, 45, 22, 24, 58, 41, 24, 52, 46, 68, 33, 55, 39, 35, 47, 63, 27, 41, 23, 50, 59, 26, 65, 51, 56, 41, 63, 21, 19, 47, 52, 44, 28, 21, 58, 57, 58, 56, 33, 27, 57, 28, 18, 54, 34, 45, 31, 58, 49, 63, 35, 57, 69, 47, 46, 56, 29, 57, 23, 33, 22, 25, 69, 21, 25, 34, 68, 66, 47]

# %%
# hacer un dataframe con las edades

df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     60
# 1     64
# 2     54
# 3     27
# 4     23
# ..   ...
# 95    25
# 96    34
# 97    68
# 98    66
# 99    47
#
# [100 rows x 1 columns]

# %%
# Calcular los intervalos utilizando la regla de Sturges

n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, "\nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    18
# 1  (47.714, 55.143]    18
# 2  (40.286, 47.714]    17
# 3  (17.947, 25.429]    14
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    11
# 6  (25.429, 32.857]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo que tengamos
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3  (17.947, 25.429]    14
# 6  (25.429, 32.857]     9
# 0  (32.857, 40.286]    18
# 2  (40.286, 47.714]    17
# 1  (47.714, 55.143]    18
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    11

# %%
# generar columnas siguientes

tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 3  (17.947, 25.429]    14      0.14       14.0       14         0.14
# 6  (25.429, 32.857]     9      0.09        9.0       23         0.23
# 0  (32.857, 40.286]    18      0.18       18.0       41         0.41
# 2  (40.286, 47.714]    17      0.17       17.0       58         0.58
# 1  (47.714, 55.143]    18      0.18       18.0       76         0.76
# 4  (55.143, 62.571]    13      0.13       13.0       89         0.89
# 5    (62.571, 70.0]    11      0.11       11.0      100         1.00
#
#    Frec Porc Ac
# 3          14.0
# 6          23.0
# 0          41.0
# 2          58.0
# 1          76.0
# 4          89.0
# 5         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia

plt.hist(df["Edad"], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
